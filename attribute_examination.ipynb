# %%
import pandas as pd

# %%
# load data/CelebAMask-HQ/CelebA-HQ-attribute-anno.txt
df = pd.read_csv('data/CelebAMask-HQ/CelebAMask-HQ-attribute-anno.txt', sep='\s+', header=1)

# %%
df.head()
# Out:
#        5_o_Clock_Shadow  Arched_Eyebrows  Attractive  Bags_Under_Eyes  Bald  \
# 0.jpg                -1                1           1                1    -1
# 1.jpg                -1                1           1               -1    -1
# 2.jpg                -1               -1           1                1    -1
# 3.jpg                -1               -1           1               -1    -1
# 4.jpg                -1               -1          -1               -1    -1
#
#        Bangs  Big_Lips  Big_Nose  Black_Hair  Blond_Hair  ...  Sideburns  \
# 0.jpg     -1         1        -1          -1          -1  ...         -1
# 1.jpg     -1        -1        -1          -1           1  ...         -1
# 2.jpg     -1         1        -1          -1          -1  ...         -1
# 3.jpg     -1        -1         1           1          -1  ...         -1
# 4.jpg     -1         1        -1          -1          -1  ...         -1
#
# ...

# %%
# replace -1 with 0
df = df.replace(-1, 0)

# %%
# create correlation matrix of attributes
corr = df.corr()
corr
# Out:
#                      5_o_Clock_Shadow  Arched_Eyebrows  Attractive  \
# 5_o_Clock_Shadow             1.000000        -0.254600   -0.114029
# Arched_Eyebrows             -0.254600         1.000000    0.252284
# Attractive                  -0.114029         0.252284    1.000000
# Bags_Under_Eyes              0.231230        -0.166099   -0.236487
# Bald                         0.019895        -0.088371   -0.173876
# Bangs                       -0.119219        -0.035892    0.044733
# Big_Lips                    -0.099329         0.182005    0.073295
# Big_Nose                     0.205112        -0.149850   -0.347663
# Black_Hair                   0.125720        -0.001246   -0.030340
# Blond_Hair                  -0.173349         0.139441    0.163690
# Blurry                      -0.004448        -0.037823   -0.061462
# Brown_Hair                  -0.017887         0.021696    0.119743
# Bushy_Eyebrows               0.243862        -0.047133    0.017099
# ...

# %%
# filter the matrix for attribute list
attribute_list = ['Male', 'Young', 'Bald', 'Bangs', 'Receding_Hairline', 'Black_Hair', 'Blond_Hair', 'Brown_Hair', 'Gray_Hair', 'Straight_Hair', 'Wavy_Hair', 'No_Beard', 'Goatee', 'Mustache', 'Sideburns', 'Narrow_Eyes', 'Oval_Face', 'Pale_Skin', 'Pointy_Nose']

corr = corr[attribute_list]
corr = corr.loc[attribute_list]
corr
# Out:
#                        Male     Young      Bald     Bangs  Receding_Hairline  \
# Male               1.000000 -0.326141  0.203626 -0.156633           0.145840
# Young             -0.326141  1.000000 -0.219848  0.025940          -0.215558
# Bald               0.203626 -0.219848  1.000000 -0.073257           0.163088
# Bangs             -0.156633  0.025940 -0.073257  1.000000          -0.142277
# Receding_Hairline  0.145840 -0.215558  0.163088 -0.142277           1.000000
# Black_Hair         0.127560  0.113154 -0.079568 -0.040589           0.004657
# Blond_Hair        -0.307356  0.068760 -0.070780  0.091590          -0.086777
# Brown_Hair        -0.100246  0.103304 -0.085415  0.057084          -0.107895
# Gray_Hair          0.192930 -0.372756  0.195142 -0.067644           0.285566
# Straight_Hair      0.065105  0.059374 -0.076217  0.043170          -0.062635
# Wavy_Hair         -0.310004  0.097635 -0.116288  0.033419          -0.116464
# ...

# %%
# visualize correlation matrix
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 20))
sns.heatmap(corr, annot=True, fmt=".2f")
plt.savefig('correlation_matrix.png')
plt.show()

# %%
# get lines where Blond_Hair is 1 and Black_Hair is 1
df[(df['Arched_Eyebrows'] == 1) & (df['Bushy_Eyebrows'] == 0)]
# Out:
#            5_o_Clock_Shadow  Arched_Eyebrows  Attractive  Bags_Under_Eyes  \
# 1.jpg                     0                1           1                0
# 8.jpg                     0                1           1                0
# 10.jpg                    1                1           0                0
# 12.jpg                    0                1           0                0
# 18.jpg                    0                1           1                0
# ...                     ...              ...         ...              ...
# 29986.jpg                 0                1           0                0
# 29989.jpg                 0                1           1                0
# 29990.jpg                 0                1           1                0
# 29994.jpg                 0                1           1                0
# 29998.jpg                 0                1           1                0
#
#            Bald  Bangs  Big_Lips  Big_Nose  Black_Hair  Blond_Hair  ...  \
# ...

# %%
df[df['Pale_Skin'] == 1]
# Out:
#            5_o_Clock_Shadow  Arched_Eyebrows  Attractive  Bags_Under_Eyes  \
# 18.jpg                    0                1           1                0
# 90.jpg                    0                1           1                0
# 100.jpg                   0                0           1                1
# 117.jpg                   0                1           0                0
# 120.jpg                   0                0           1                0
# ...                     ...              ...         ...              ...
# 29918.jpg                 0                0           1                0
# 29938.jpg                 0                1           1                0
# 29951.jpg                 0                0           1                0
# 29952.jpg                 0                0           1                0
# 29968.jpg                 0                0           0                0
#
#            Bald  Bangs  Big_Lips  Big_Nose  Black_Hair  Blond_Hair  ...  \
# ...

# %%
selected = ['Male', 'Young', 'Bald', 'Bangs', 'Receding_Hairline', 'Black_Hair', 'Blond_Hair', 'Brown_Hair', 'Gray_Hair', 'Straight_Hair', 'Wavy_Hair', 'No_Beard', 'Goatee', 'Mustache', 'Sideburns', 'Narrow_Eyes', 'Oval_Face', 'Pale_Skin', 'Pointy_Nose']

len(selected)
# Out:
# 19

# %%
df[selected]
# Out:
#            Male  Young  Bald  Bangs  Receding_Hairline  Black_Hair  \
# 0.jpg         0      1     0      0                  0           0
# 1.jpg         0      1     0      0                  0           0
# 2.jpg         0      1     0      0                  0           0
# 3.jpg         0      1     0      0                  0           1
# 4.jpg         0      1     0      0                  0           0
# ...         ...    ...   ...    ...                ...         ...
# 29995.jpg     1      0     0      0                  0           0
# 29996.jpg     1      1     0      0                  0           0
# 29997.jpg     0      1     0      1                  0           1
# 29998.jpg     0      1     0      0                  0           0
# 29999.jpg     0      0     0      1                  0           0
#
#            Blond_Hair  Brown_Hair  Gray_Hair  Straight_Hair  Wavy_Hair  \
# 0.jpg               0           1          0              0          1
# ...
